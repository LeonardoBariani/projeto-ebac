# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
# importar bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# carregar base num dataframe
previsao_de_renda = pd.read_csv('previsao_de_renda.csv')

# %%
previsao_de_renda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   index                  15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12466 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %%
previsao_de_renda.head(n = 5)
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
print("Valores únicos da variável 'data_ref':", previsao_de_renda['data_ref'].unique())
print("Valores únicos da variável 'sexo':", previsao_de_renda['sexo'].unique())
print("Valores únicos da variável 'posse_de_veiculo':", previsao_de_renda['posse_de_veiculo'].unique())
print("Valores únicos da variável 'posse_de_imovel':", previsao_de_renda['posse_de_imovel'].unique())
print("Valores únicos da variável 'tipo_renda':", previsao_de_renda['tipo_renda'].unique())
print("Valores únicos da variável 'educacao':", previsao_de_renda['educacao'].unique())
print("Valores únicos da variável 'estado_civil':", previsao_de_renda['estado_civil'].unique())
print("Valores únicos da variável 'tipo_residencia':", previsao_de_renda['tipo_residencia'].unique())
# Out:
# Valores únicos da variável 'data_ref': ['2015-01-01' '2015-02-01' '2015-03-01' '2015-04-01' '2015-05-01'
#  '2015-06-01' '2015-07-01' '2015-08-01' '2015-09-01' '2015-10-01'
#  '2015-11-01' '2015-12-01' '2016-01-01' '2016-02-01' '2016-03-01']
# Valores únicos da variável 'sexo': ['F' 'M']
# Valores únicos da variável 'posse_de_veiculo': [False  True]
# Valores únicos da variável 'posse_de_imovel': [ True False]
# Valores únicos da variável 'tipo_renda': ['Assalariado' 'Empresário' 'Servidor público' 'Pensionista' 'Bolsista']
# Valores únicos da variável 'educacao': ['Secundário' 'Superior completo' 'Superior incompleto' 'Primário'
#  'Pós graduação']
# Valores únicos da variável 'estado_civil': ['Casado' 'União' 'Solteiro' 'Separado' 'Viúvo']
# Valores únicos da variável 'tipo_residencia': ['Casa' 'Com os pais' 'Aluguel' 'Governamental' 'Estúdio' 'Comunitário']

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %% [markdown]
# ##### Variável sexo

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'sexo', palette = ['pink', 'blue'])

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Sexo')
plt.title('Quantidade de homens e mulheres por período')
plt.legend(title = 'Sexo')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável posse de veiculo

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'posse_de_veiculo')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Posse de veículo')
plt.title('Quantidade de pessoas que possuem e não possuem veículos por período')
plt.legend(title = 'Posse de veículo')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável posse de imóvel

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'posse_de_imovel')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Posse de imóvel')
plt.title('Quantidade de pessoas que possuem e não possuem imóveis por período')
plt.legend(title = 'Posse de imóvel')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável tipo de renda

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'tipo_renda')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Tipo de renda')
plt.title('Quantidade de pessoas por tipo de renda')
plt.legend(title = 'Tipo de renda')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável educação

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'educacao')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Educação')
plt.title('Quantidade de pessoas por nível de escolaridade')
plt.legend(title = 'Educação')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável estado civil

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'estado_civil')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Estado civil')
plt.title('Quantidade de pessoas por estado civil')
plt.legend(title = 'Estado civil')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ##### Variável tipo de residência

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados
sns.countplot(data = previsao_de_renda, x = 'data_ref', hue = 'tipo_residencia')

# configurações adicionais
plt.xlabel('Data de referência')
plt.ylabel('Tipo de residência')
plt.title('Quantidade de pessoas por tipo de residência')
plt.legend(title = 'Tipo de residência')

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### Identificamos uma variação dos resultados dentro da variável 'escolaridade', especificamente entre os períodos de agosto à setembro de 2015. Nestes períodos, nota-se uma queda da quantidade de pessoas com ensino secundário completo. Em contrapartida, houve um crescimento das pessoas com ensino superior completo.

# %% [markdown]
# 2) Para cada variável QUANTITATIVA, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %% [markdown]
# ### Variável renda

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = sexo)
sns.pointplot(x = 'data_ref', y = 'renda', hue = 'sexo', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = tipo de renda)
sns.pointplot(x = 'data_ref', y = 'renda', hue = 'tipo_renda', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = educação)
sns.pointplot(x = 'data_ref', y = 'renda', hue = 'educacao', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = estado civil)
sns.pointplot(x = 'data_ref', y = 'renda', hue = 'estado_civil', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = tipo de residencia)
sns.pointplot(x = 'data_ref', y = 'renda', hue = 'tipo_residencia', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### Assim como identificado nos gráficos de barra, os dados da variável educação tendem a apresentar instabilidade no tempo. Os dados de pós graduação, por exemplo, possuem medias que oscilam de 4 mil à 16 mil, além duma maior variabilidade refletida no maior comprimento das barras de erro.
#
# ### Outra variável que chama atenção é o tipo de residência. Quando olhamos os dados do valor comunitário, há uma oscilação significativa nos valores médios, além uma maior variabilidade dos dados em torno do cálculo da média.
#
# ### Por fim, a variável tipo de renda, para o valor bolsista, apresenta apenas três registros dos quinze possíveis, além de possuir uma diferença considerável na renda média para cada um destes três registros.

# %% [markdown]
# ### Variável tempo de emprego

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = sexo)
sns.pointplot(x = 'data_ref', y = 'tempo_emprego', hue = 'sexo', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = tipo de renda)
sns.pointplot(x = 'data_ref', y = 'tempo_emprego', hue = 'tipo_renda', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = educação)
sns.pointplot(x = 'data_ref', y = 'tempo_emprego', hue = 'educacao', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = estado civil)
sns.pointplot(x = 'data_ref', y = 'tempo_emprego', hue = 'estado_civil', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %%
# define altura e comprimento do gráfico
plt.figure(figsize = (10, 6))

# plotar os dados (hue = tipo de residência)
sns.pointplot(x = 'data_ref', y = 'tempo_emprego', hue = 'tipo_residencia', data = previsao_de_renda, dodge = True, errorbar = ('ci', 95))

# rotacionar os valores do eixo x
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### Para a variável quantitativo tempo de emprego, diferentemente da variável renda, observamos problemas em todas as variáveis qualitativas.
#
# ### Para todas as variáveis qualitativas, há poucos registros e diferenças nos valores médios (exemplo: tipo de renda igual à pensionista), oscilação nos valores médio minimos e máximos, além duma maior variabilidade dos dados dentro do cálculo médio (exemplo: tipo de residência igual à comunitário, estado civil igual à viuvo e educação igual à pos graduação).
#
# ### Estes problemas citados acima nas variáveis qualitativas podem acarretar numa menor confiança na predição da variável tempo de emprego.

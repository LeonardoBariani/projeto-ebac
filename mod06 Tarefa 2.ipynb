# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
# importando todas as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# leitura da base sinasc_RO_2019
sinasc_RO_2019 = pd.read_csv('SINASC_RO_2019.csv')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(y = "IDADEMAE", data = sinasc_RO_2019)
# Out:
# <Axes: ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y = "PESO", data = sinasc_RO_2019)
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(data = sinasc_RO_2019, alpha = .50, x = 'IDADEMAE', bins = 20, element = 'step', kde = True)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.displot(data = sinasc_RO_2019, alpha = .50, x = 'PESO', bins = 20, element = 'step', kde = True)
